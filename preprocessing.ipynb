# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#reading the data
train = pd.read_csv('train.tsv',delimiter='\t')
test = pd.read_csv('test.tsv',delimiter='\t')

#dimensions 
print("Shape of train :", train.shape)
print("Shape of test :", test.shape)
# Out:
# Shape of train : (161297, 7)
# Shape of test : (53766, 7)

# %%
train.head()
# Out:
#    Unnamed: 0                  drugName                     condition  \
# 0      206461                 Valsartan  Left Ventricular Dysfunction
# 1       95260                Guanfacine                          ADHD
# 2       92703                    Lybrel                 Birth Control
# 3      138000                Ortho Evra                 Birth Control
# 4       35696  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating  \
# 0  "It has no side effect, I take it in combinati...     9.0
# 1  "My son is halfway through his fourth week of ...     8.0
# 2  "I used to take another oral contraceptive, wh...     5.0
# 3  "This is my first time using any form of birth...     8.0
# 4  "Suboxone has completely turned my life around...     9.0
#
#                 date  usefulCount
# 0       May 20, 2012           27
# 1     April 27, 2010          192
# 2  December 14, 2009           17
# 3   November 3, 2015           10
# 4  November 27, 2016           37

# %%
len(train['drugName'].unique())
# Out:
# 3436

# %% [markdown]
# **Preprocessing**

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161297 entries, 0 to 161296
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   161297 non-null  int64
#  1   drugName     161297 non-null  object
#  2   condition    160398 non-null  object
#  3   review       161297 non-null  object
#  4   rating       161297 non-null  float64
#  5   date         161297 non-null  object
#  6   usefulCount  161297 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.6+ MB

# %%
train.isnull().sum()/len(train)
# Out:
# Unnamed: 0     0.000000
# drugName       0.000000
# condition      0.005574
# review         0.000000
# rating         0.000000
# date           0.000000
# usefulCount    0.000000
# dtype: float64

# %%
#since the percent of null values is less than 1%
train.dropna(inplace=True)
train.reset_index(inplace=True)

# %%
train.groupby(['condition']).nunique()
# Out:
#                                               index  Unnamed: 0  drugName  \
# condition
# 0</span> users found this comment helpful.      104         104        42
# 10</span> users found this comment helpful.      28          28        28
# 110</span> users found this comment helpful.      1           1         1
# 11</span> users found this comment helpful.      10          10        10
# 121</span> users found this comment helpful.      1           1         1
# ...                                             ...         ...       ...
# unctional Gastric Disorde                         1           1         1
# ungal Infection Prophylaxis                       1           1         1
# ungal Pneumonia                                   1           1         1
# von Willebrand's Disease                          7           7         3
# zen Shoulde                                      14          14         8
#
#                                               condition  review  rating  date  \
# condition
# 0</span> users found this comment helpful.            1     104      10    99
# 10</span> users found this comment helpful.           1      28       9    28
# 110</span> users found this comment helpful.          1       1       1     1
# 11</span> users found this comment helpful.           1      10       6    10
# 121</span> users found this comment helpful.          1       1       1     1
# ...                                                 ...     ...     ...   ...
# unctional Gastric Disorde                             1       1       1     1
# ungal Infection Prophylaxis                           1       1       1     1
# ungal Pneumonia                                       1       1       1     1
# von Willebrand's Disease                              1       5       1     5
# zen Shoulde                                           1      11       7    10
#
#                                               usefulCount
# condition
# 0</span> users found this comment helpful.              1
# 10</span> users found this comment helpful.             1
# 110</span> users found this comment helpful.            1
# 11</span> users found this comment helpful.             1
# 121</span> users found this comment helpful.            1
# ...                                                   ...
# unctional Gastric Disorde                               1
# ungal Infection Prophylaxis                             1
# ungal Pneumonia                                         1
# von Willebrand's Disease                                4
# zen Shoulde                                            10
#
# [884 rows x 8 columns]

# %% [markdown]
# *There are some comments in condition column which are not helpful.*

# %%
#dropping unwanted observations
x = train[train["condition"].str.contains("</span>",na=False)].index
train.drop(train.index[x],inplace=True)

# %%
train.groupby(['condition']).nunique()
# Out:
#                              index  Unnamed: 0  drugName  condition  review  \
# condition
# ADHD                          3383        3383        55          1    2192
# AIDS Related Wasting             5           5         3          1       4
# AV Heart Block                   1           1         1          1       1
# Abdominal Distension             2           2         2          1       1
# Abnormal Uterine Bleeding     2096        2096        74          1    1340
# ...                            ...         ...       ...        ...     ...
# unctional Gastric Disorde        1           1         1          1       1
# ungal Infection Prophylaxis      1           1         1          1       1
# ungal Pneumonia                  1           1         1          1       1
# von Willebrand's Disease         7           7         3          1       5
# zen Shoulde                     14          14         8          1      11
#
#                              rating  date  usefulCount
# condition
# ADHD                             10  1531          170
# AIDS Related Wasting              4     4            4
# AV Heart Block                    1     1            1
# Abdominal Distension              1     1            1
# Abnormal Uterine Bleeding        10   930           85
# ...                             ...   ...          ...
# unctional Gastric Disorde         1     1            1
# ungal Infection Prophylaxis       1     1            1
# ungal Pneumonia                   1     1            1
# von Willebrand's Disease          1     5            4
# zen Shoulde                       7    10           10
#
# [811 rows x 8 columns]

# %%
len(x)
# Out:
# 900

# %%
train.head()
# Out:
#    index  Unnamed: 0                  drugName                     condition  \
# 0      0      206461                 Valsartan  Left Ventricular Dysfunction
# 1      1       95260                Guanfacine                          ADHD
# 2      2       92703                    Lybrel                 Birth Control
# 3      3      138000                Ortho Evra                 Birth Control
# 4      4       35696  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating  \
# 0  "It has no side effect, I take it in combinati...     9.0
# 1  "My son is halfway through his fourth week of ...     8.0
# 2  "I used to take another oral contraceptive, wh...     5.0
# 3  "This is my first time using any form of birth...     8.0
# 4  "Suboxone has completely turned my life around...     9.0
#
#                 date  usefulCount
# 0       May 20, 2012           27
# 1     April 27, 2010          192
# 2  December 14, 2009           17
# 3   November 3, 2015           10
# 4  November 27, 2016           37

# %%
def clean(x): 
    return ' '.join(re.sub("&#039|&amp;|(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", x).split())

# %%
train['review'] = [clean(x) for x in train['review']]

# %%
train.head()
# Out:
#    index  Unnamed: 0                  drugName                     condition  \
# 0      0      206461                 Valsartan  Left Ventricular Dysfunction
# 1      1       95260                Guanfacine                          ADHD
# 2      2       92703                    Lybrel                 Birth Control
# 3      3      138000                Ortho Evra                 Birth Control
# 4      4       35696  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating  \
# 0  It has no side effect I take it in combination...     9.0
# 1  My son is halfway through his fourth week of I...     8.0
# 2  I used to take another oral contraceptive whic...     5.0
# 3  This is my first time using any form of birth ...     8.0
# 4  Suboxone has completely turned my life around ...     9.0
#
#                 date  usefulCount
# 0       May 20, 2012           27
# 1     April 27, 2010          192
# 2  December 14, 2009           17
# 3   November 3, 2015           10
# 4  November 27, 2016           37

# %%
index_1 = train.groupby(['drugName']).count().sort_values(by='condition')[:797].index
index_2 = train[train['drugName'].isin(list(index_1))].index
train.drop(list(index_2),inplace=True)

# %%
index_3 = train.groupby(['condition']).count().sort_values(by='drugName')[:117].index
index_4 = train[train['condition'].isin(list(index_3))].index
train.drop(list(index_4),inplace=True)

# %%
train.head(10)
# Out:
#    index  Unnamed: 0                            drugName  \
# 0      0      206461                           Valsartan
# 1      1       95260                          Guanfacine
# 2      2       92703                              Lybrel
# 3      3      138000                          Ortho Evra
# 4      4       35696            Buprenorphine / naloxone
# 5      5      155963                              Cialis
# 6      6      165907                      Levonorgestrel
# 7      7      102654                        Aripiprazole
# 8      8       74811                              Keppra
# 9      9       48928  Ethinyl estradiol / levonorgestrel
#
#                       condition  \
# 0  Left Ventricular Dysfunction
# 1                          ADHD
# 2                 Birth Control
# 3                 Birth Control
# 4             Opiate Dependence
# 5  Benign Prostatic Hyperplasia
# 6       Emergency Contraception
# 7               Bipolar Disorde
# 8                      Epilepsy
# 9                 Birth Control
#
#                                               review  rating  \
# 0  It has no side effect I take it in combination...     9.0
# 1  My son is halfway through his fourth week of I...     8.0
# 2  I used to take another oral contraceptive whic...     5.0
# 3  This is my first time using any form of birth ...     8.0
# 4  Suboxone has completely turned my life around ...     9.0
# 5  2nd day on 5mg started to work with rock hard ...     2.0
# 6  He pulled out but he cummed a bit in me I took...     1.0
# 7  Abilify changed my life There is hope I was on...    10.0
# 8  I Ve had nothing but problems with the Keppera...     1.0
# 9  I had been on the pill for many years When my ...     8.0
#
#                 date  usefulCount
# 0       May 20, 2012           27
# 1     April 27, 2010          192
# 2  December 14, 2009           17
# 3   November 3, 2015           10
# 4  November 27, 2016           37
# 5  November 28, 2015           43
# 6      March 7, 2017            5
# 7     March 14, 2015           32
# 8     August 9, 2016           11
# 9   December 8, 2016            1

# %%
train.shape
# Out:
# (158584, 8)

# %%
train.drop(['index','Unnamed: 0'],axis=1,inplace=True)

# %%
train.to_csv("train_new.csv")
